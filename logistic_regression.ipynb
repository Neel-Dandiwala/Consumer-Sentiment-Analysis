# %%
#install needed packages
# !pip install snorkel
# !pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snorkel in /usr/local/lib/python3.10/dist-packages (0.9.9)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (4.65.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from snorkel) (2.12.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.22.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.5.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.2.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from snorkel) (3.1)
# Requirement already satisfied: munkres>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.1.4)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (2.0.0+cu118)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->snorkel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->snorkel) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.2->snorkel) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.2->snorkel) (3.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (67.7.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.27.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (0.40.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.51.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (3.20.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.17.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.8.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (4.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (3.12.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2.0->snorkel) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2.0->snorkel) (16.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->snorkel) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->snorkel) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.2.0->snorkel) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->snorkel) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.2.0)

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
print(locale.getpreferredencoding())
# Out:
# UTF-8

# %%
pip install scikit-learn-intelex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn-intelex in /usr/local/lib/python3.10/dist-packages (2023.1.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-intelex) (1.2.2)
# Requirement already satisfied: daal4py==2023.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-intelex) (2023.1.1)
# Requirement already satisfied: daal==2023.1.1 in /usr/local/lib/python3.10/dist-packages (from daal4py==2023.1.1->scikit-learn-intelex) (2023.1.1)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from daal4py==2023.1.1->scikit-learn-intelex) (1.22.4)
# Requirement already satisfied: tbb==2021.* in /usr/local/lib/python3.10/dist-packages (from daal==2023.1.1->daal4py==2023.1.1->scikit-learn-intelex) (2021.9.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.10.1)

# %%
from sklearnex import patch_sklearn

# %%
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
pip install "modin[all]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: modin[all] in /usr/local/lib/python3.10/dist-packages (0.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from modin[all]) (23.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (1.22.4)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (1.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from modin[all]) (5.9.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from modin[all]) (2023.4.0)
# Requirement already satisfied: unidist[mpi]>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (0.3.0)
# Requirement already satisfied: dask>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (2022.12.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from modin[all]) (9.0.0)
# Requirement already satisfied: ray[default]>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (2.4.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from modin[all]) (2.2.1)
# Requirement already satisfied: rpyc==4.1.5 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (4.1.5)
# Requirement already satisfied: distributed>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (2022.12.1)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (1.26.127)
# Requirement already satisfied: modin-spreadsheet>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from modin[all]) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3->modin[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3->modin[all]) (2022.7.1)
# Requirement already satisfied: plumbum in /usr/local/lib/python3.10/dist-packages (from rpyc==4.1.5->modin[all]) (1.8.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2.22.0->modin[all]) (8.1.3)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask>=2.22.0->modin[all]) (1.4.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask>=2.22.0->modin[all]) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2.22.0->modin[all]) (6.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (1.7.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (3.0.0)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (1.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (6.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (3.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (1.26.15)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (2.4.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.22.0->modin[all]) (1.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from modin-spreadsheet>=0.1.0->modin[all]) (7.7.1)
# Requirement already satisfied: jupyter>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from modin-spreadsheet>=0.1.0->modin[all]) (1.0.0)
# Requirement already satisfied: notebook>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from modin-spreadsheet>=0.1.0->modin[all]) (6.4.8)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (1.3.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (23.1.0)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (20.21.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (3.12.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (2.27.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (4.3.3)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (1.3.3)
# Requirement already satisfied: grpcio<=1.51.3,>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (1.51.3)
# Requirement already satisfied: colorful in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (0.5.5)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (0.16.0)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (0.7.0)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (0.3.14)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (0.11.2)
# Requirement already satisfied: aiohttp>=3.7 in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (3.8.4)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (6.3.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (1.10.7)
# Requirement already satisfied: gpustat>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[default]>=1.13.0->modin[all]) (1.1)
# Requirement already satisfied: mpi4py-mpich in /usr/local/lib/python3.10/dist-packages (from unidist[mpi]>=0.2.1->modin[all]) (3.1.2)
# Requirement already satisfied: botocore<1.30.0,>=1.29.127 in /usr/local/lib/python3.10/dist-packages (from boto3->modin[all]) (1.29.127)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->modin[all]) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3->modin[all]) (0.6.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (4.0.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]>=1.13.0->modin[all]) (6.0.4)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /usr/local/lib/python3.10/dist-packages (from gpustat>=1.0.0->ray[default]>=1.13.0->modin[all]) (11.525.112)
# Requirement already satisfied: blessed>=1.17.1 in /usr/local/lib/python3.10/dist-packages (from gpustat>=1.0.0->ray[default]>=1.13.0->modin[all]) (1.20.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.5.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.7)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.6.4)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.1.0)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.4.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.8.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (6.1.12)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (23.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3->modin[all]) (1.16.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]>=1.13.0->modin[all]) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]>=1.13.0->modin[all]) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->distributed>=2.22.0->modin[all]) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default]>=1.13.0->modin[all]) (0.19.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default]>=1.13.0->modin[all]) (2.11.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default]>=1.13.0->modin[all]) (0.1.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->ray[default]>=1.13.0->modin[all]) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[default]>=1.13.0->modin[all]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[default]>=1.13.0->modin[all]) (2022.12.7)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]>=1.13.0->modin[all]) (0.2.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.13.0->modin[all]) (1.59.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.13.0->modin[all]) (2.17.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.14.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (67.7.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.1.6)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (21.2.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.9.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.11.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.16.3)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from qtconsole->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.13.0->modin[all]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.13.0->modin[all]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.13.0->modin[all]) (4.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.8.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.21)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.13.0->modin[all]) (0.5.0)

# %%
#import libraries and modules
import io
import modin.pandas as pd
# import pandas as pd

# %%
pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (23.0.1)
# Collecting pip
#   Downloading pip-23.1.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.8 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-23.1.2

# %%
# !pip install --index-url https://pypi.anaconda.org/intel/simple --extra-index-url https://pypi.org/simple dpnp
# Out:
# Looking in indexes: https://pypi.anaconda.org/intel/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://pypi.org/simple
# ERROR: Could not find a version that satisfies the requirement dpnp (from versions: none)
# ERROR: No matching distribution found for dpnp

# %%
# import dpnp as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-96-6008480f9f11> in <cell line: 1>()
# ----> 1 import dpnp as np
#
# ModuleNotFoundError: No module named 'dpnp'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install snorkel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snorkel in /usr/local/lib/python3.10/dist-packages (0.9.9)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.22.4)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from snorkel) (2.12.2)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.2.2)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (2.0.0+cu118)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from snorkel) (3.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.5.3)
# Requirement already satisfied: munkres>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.1.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->snorkel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->snorkel) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.2->snorkel) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.2->snorkel) (1.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (67.7.2)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.51.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.3.0)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (0.7.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (0.40.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.0.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (3.12.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2.0->snorkel) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2.0->snorkel) (16.0.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->snorkel) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->snorkel) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.2.0->snorkel) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->snorkel) (3.2.2)

# %%
#Snorkel
from snorkel.labeling import LabelingFunction
import re
from snorkel.preprocess import preprocessor
from textblob import TextBlob
from snorkel.labeling import PandasLFApplier
from snorkel.labeling.model import LabelModel
from snorkel.labeling import LFAnalysis
from snorkel.labeling import filter_unlabeled_dataframe
from snorkel.labeling import labeling_function

# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.2)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.2)

# %%
#NLP packages
import spacy
from nltk.corpus import stopwords
import string
import nltk
import nltk.tokenize
punc = string.punctuation
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#Supervised learning
from tqdm import tqdm_notebook as tqdm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
##Deep learning libraries and APIs
# import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import numpy as np

# %%
# store the dataset as a Pandas Dataframe
df = pd.read_csv('train_file.csv')
df = pd.DataFrame(df)
df.head()
training_data = pd.read_csv('train_file.csv')
#conduct some data cleaning
# df = df.drop(['publish_date', 'Unnamme 'pd' is not defineded: 2'], axis=1)
# df = df.rename(columns = {'headline_text': 'text'})
# df['Title'] = df['Title'].astype(str)
#check the data info
training_data.head()
training_data.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 55932 entries, 0 to 55931
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  -----------------  --------------  -----
#  0   IDLink             55932 non-null  object
#  1   Title              55932 non-null  object
#  2   Headline           55932 non-null  object
#  3   Source             55757 non-null  object
#  4   Topic              55932 non-null  object
#  5   PublishDate        55932 non-null  object
#  6   Facebook           55932 non-null  int64
#  7   GooglePlus         55932 non-null  int64
#  8   LinkedIn           55932 non-null  int64
#  9   SentimentTitle     55932 non-null  float64
#  10  SentimentHeadline  55932 non-null  float64
# dtypes: object(6), int64(3), float64(2)
# memory usage: 4.7 MB

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
title = list(training_data['Title'])
headline = list(training_data['Headline'])

# %%
import re
title_words = [re.findall(r"[\w']+", x) for x in title]
training_data['Title'] = [re.findall(r"[\w']+", x) for x in title]
headline_words = [re.findall(r"[\w']+", x) for x in headline]
print(headline_words[0])
# Out:
# ['Obama', 'Lays', 'Wreath', 'at', 'Arlington', 'National', 'Cemetery', 'President', 'Barack', 'Obama', 'has', 'laid', 'a', 'wreath', 'at', 'the', 'Tomb', 'of', 'the', 'Unknowns', 'to', 'honor']

# %%
new_title_words = [];
for wordList in title_words:
    new_words = list(filter(lambda w: w not in stop_words,wordList))
    new_title_words.append(new_words)
new_headline_words = []
for wordList in headline_words:
    new_words = list(filter(lambda w: w not in stop_words,wordList))
    new_headline_words.append(new_words)

# %%
sentiment_titles = list(training_data['SentimentTitle'])
sentiment_headlines = list(training_data['SentimentHeadline'])

# %%
#define constants to represent the class labels :positive, negative, and abstain
POSITIVES = list()
NEGATIVES = list()
NEUTRALS =  list()
#define function which looks into the input words to represent a proper label
# def keyword_lookup(x, keywords, label):  
#     if any(word in x.text.lower() for word in keywords):
#         return label
#     return ABSTAIN
# #define function which assigns a correct label
# def make_keyword_lf(keywords, label=POSITIVE):
#     return LabelingFunction(
#         name=f"keyword_{keywords[0]}",
#         f=keyword_lookup,
#         resources=dict(keywords=keywords, label=label))




for x in range(len(sentiment_titles)):
    for i in new_headline_words[x]:
        if(sentiment_titles[x] < 0 ):
            NEGATIVES.append(i)
        elif(sentiment_titles[x] > 0 ):
            POSITIVES.append(i)
        elif(sentiment_titles[x] == 0 ):
            NEUTRALS.append(i)

# %%
#define constants to represent the class labels :positive, negative, and abstain
POSITIVES_headline = list()
NEGATIVES_headline = list()
NEUTRALS_headline =  list()
#define function which looks into the input words to represent a proper label
# def keyword_lookup(x, keywords, label):  
#     if any(word in x.text.lower() for word in keywords):
#         return label
#     return ABSTAIN
# #define function which assigns a correct label
# def make_keyword_lf(keywords, label=POSITIVE):
#     return LabelingFunction(
#         name=f"keyword_{keywords[0]}",
#         f=keyword_lookup,
#         resources=dict(keywords=keywords, label=label))




for x in range(len(sentiment_headlines)):
    for i in new_headline_words[x]:
        if(sentiment_headlines[x] < 0 ):
            NEGATIVES_headline.append(i)
        elif(sentiment_headlines[x] > 0 ):
            POSITIVES_headline.append(i)
        elif(sentiment_headlines[x] == 0 ):
            NEUTRALS_headline.append(i)

# %%
# #set up a preprocessor function to determine polarity & subjectivity using textlob pretrained classifier 
# @preprocessor(memoize=True)
# def textblob_sentiment(x):
#     scores = TextBlob(x.text)
#     x.polarity = scores.sentiment.polarity
#     x.subjectivity = scores.sentiment.subjectivity
#     return x
# #find polarity
# @labeling_function(pre=[textblob_sentiment])
# def textblob_polarity(x):
#     return POSITIVES if x.polarity > 0.6 else NEUTRALS
# #find subjectivity 
# @labeling_function(pre=[textblob_sentiment])
# def textblob_subjectivity(x):
#     return POSITIVES if x.subjectivity >= 0.5 else NEUTRALS
# def keyword_lookup(x, keywords, label):  
#     if any(word in x.text.lower() for word in keywords):
#         return label
#     return "NEUTRAL"
# def make_keyword_lf(keywords, label="POSITIVE"):
#     return LabelingFunction(
#         name=f"keyword_{keywords[0]}",
#         f=keyword_lookup,
#         resources=dict(keywords=keywords, label=label))
# #combine all the labeling functions 
# lfs = [make_keyword_lf(POSITIVES_headline), make_keyword_lf(NEGATIVES_headline), textblob_polarity, textblob_subjectivity]
# #apply the lfs on the dataframe
# print(lfs)
# applier = PandasLFApplier(lfs=lfs)
# print(applier)
# # L_snorkel = applier.apply(df=df)
# L_snorkel = applier.parallel_apply(df=df)
# Out:
# [LabelingFunction keyword_Nouriel, Preprocessors: [], LabelingFunction keyword_Obama, Preprocessors: [], LabelingFunction textblob_polarity, Preprocessors: [LambdaMapper textblob_sentiment, Pre: []], LabelingFunction textblob_subjectivity, Preprocessors: [LambdaMapper textblob_sentiment, Pre: []]]
# PandasLFApplier, LFs: ['keyword_Nouriel', 'keyword_Obama', 'textblob_polarity', 'textblob_subjectivity']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-ffa13a5e62d3> in <cell line: 32>()
#      30 print(applier)
#      31 # L_snorkel = applier.apply(df=df)
# ---> 32 L_snorkel = applier.parallel_apply(df=df)
#
# AttributeError: 'PandasLFApplier' object has no attribute 'parallel_apply'

# %%
new_title_words_df = pd.DataFrame(new_title_words)
new_headline_words_df = pd.DataFrame(new_headline_words)
new_headline_words_df
# Out:
#               0         1           2            3          4          5   \
# 0          Obama      Lays      Wreath    Arlington   National   Cemetery
# 1            Tim   Haywood  investment     director   business       unit
# 2        Nouriel   Roubini         NYU    professor   chairman    Roubini
# 3      Finland's   economy    expanded   marginally      three     months
# 4        Tourism    public    spending    continued      boost    economy
# ...          ...       ...         ...          ...        ...        ...
# 55927    Retired     Cuban      leader        Fidel     Castro    slammed
# 55928  President     Obama      caught  predictable       flak  political
# 55929      While     Trump       wants          put      large    tariffs
# 55930  Microsoft  business   customers      finally  beginning       take
# 55931         AS        WE        know    listening   campaign   rhetoric
#
#                6          7            8         9   ...    51    52    53  \
# 0       President     Barack        Obama      laid  ...  None  None  None
# 1            head      fixed       income       Gam  ...  None  None  None
# 2          Global  Economics     explains    global  ...  None  None  None
# 3           ended   December  contracting  previous  ...  None  None  None
# 4         January      light  contraction   private  ...  None  None  None
# ...           ...        ...          ...       ...  ...   ...   ...   ...
# 55927   President     Barack      Obama's    recent  ...  None  None  None
# 55928       right        way      reacted     react  ...  None  None  None
# 55929     imports      major      trading  partners  ...  None  None  None
# 55930    delivery      giant      Windows        10  ...  None  None  None
# 55931  candidates    parties            U         S  ...  None  None  None
#
#          54    55    56    57    58    59    60
# 0      None  None  None  None  None  None  None
# 1      None  None  None  None  None  None  None
# 2      None  None  None  None  None  None  None
# 3      None  None  None  None  None  None  None
# 4      None  None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...   ...
# 55927  None  None  None  None  None  None  None
# 55928  None  None  None  None  None  None  None
# 55929  None  None  None  None  None  None  None
# 55930  None  None  None  None  None  None  None
# 55931  None  None  None  None  None  None  None
#
# [55932 rows x 61 columns]

# %%
new_title_words_df = new_title_words_df.fillna('')
new_headline_words_df = new_headline_words_df.fillna('')
new_headline_words_df
# Out:
#               0         1           2            3          4          5   \
# 0          Obama      Lays      Wreath    Arlington   National   Cemetery
# 1            Tim   Haywood  investment     director   business       unit
# 2        Nouriel   Roubini         NYU    professor   chairman    Roubini
# 3      Finland's   economy    expanded   marginally      three     months
# 4        Tourism    public    spending    continued      boost    economy
# ...          ...       ...         ...          ...        ...        ...
# 55927    Retired     Cuban      leader        Fidel     Castro    slammed
# 55928  President     Obama      caught  predictable       flak  political
# 55929      While     Trump       wants          put      large    tariffs
# 55930  Microsoft  business   customers      finally  beginning       take
# 55931         AS        WE        know    listening   campaign   rhetoric
#
#                6          7            8         9   ... 51 52 53 54 55 56 57  \
# 0       President     Barack        Obama      laid  ...
# 1            head      fixed       income       Gam  ...
# 2          Global  Economics     explains    global  ...
# 3           ended   December  contracting  previous  ...
# 4         January      light  contraction   private  ...
# ...           ...        ...          ...       ...  ... .. .. .. .. .. .. ..
# 55927   President     Barack      Obama's    recent  ...
# 55928       right        way      reacted     react  ...
# 55929     imports      major      trading  partners  ...
# 55930    delivery      giant      Windows        10  ...
# 55931  candidates    parties            U         S  ...
#
#       58 59 60
# 0
# 1
# 2
# 3
# 4
# ...   .. .. ..
# 55927
# 55928
# 55929
# 55930
# 55931
#
# [55932 rows x 61 columns]

# %%
tfidf_vect = TfidfVectorizer()
new_title_words_df
# new_title_words_df = new_title_words_df.apply(lambda text: " ".join(set(text)),axis=1)
new_title_words_df['Title'] = new_title_words_df[new_title_words_df.columns[1:]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

# # new_title_words_df

# %%
new_title_words_df = new_title_words_df.iloc[:,25:]

# %%
new_title_words_df
# Out:
#                                                    Title
# 0      Lays Wreath Arlington National Cemetery       ...
# 1        Look Health Chinese Economy
# 2      Roubini Global Economy Not Back 2008          ...
# 3                  GDP Expands In Q4
# 4      govt spending buoys Thai economy January      ...
# ...                                                  ...
# 55927  Castro Lashes Out Obama After Cuba Visit      ...
# 55928  CRISP Obama's strategic reaction Brussels     ...
# 55929  Trump's 45 Percent Tariffs Are Bad Try Obama's...
# 55930  finally releases giant Surface                ...
# 55931           sunshine US economy
#
# [55932 rows x 1 columns]

# %%
# tfidf_vect = TfidfVectorizer()
# new_headline_words_df
# new_title_words_df = new_title_words_df.apply(lambda text: " ".join(set(text)),axis=1)
new_headline_words_df['Headline'] = new_headline_words_df[new_headline_words_df.columns[1:]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)
# new_headline_words_df = new_headline_words_df.iloc[:,61:]

# # print((new_headline_words_df))
# # new_title_words_df

# %%
new_headline_words_df
# Out:
#                0         1           2            3          4          5  \
# 0          Obama      Lays      Wreath    Arlington   National   Cemetery
# 1            Tim   Haywood  investment     director   business       unit
# 2        Nouriel   Roubini         NYU    professor   chairman    Roubini
# 3      Finland's   economy    expanded   marginally      three     months
# 4        Tourism    public    spending    continued      boost    economy
# ...          ...       ...         ...          ...        ...        ...
# 55927    Retired     Cuban      leader        Fidel     Castro    slammed
# 55928  President     Obama      caught  predictable       flak  political
# 55929      While     Trump       wants          put      large    tariffs
# 55930  Microsoft  business   customers      finally  beginning       take
# 55931         AS        WE        know    listening   campaign   rhetoric
#
#                 6          7            8         9  ... 52 53 54 55 56 57 58  \
# 0       President     Barack        Obama      laid  ...
# 1            head      fixed       income       Gam  ...
# 2          Global  Economics     explains    global  ...
# 3           ended   December  contracting  previous  ...
# 4         January      light  contraction   private  ...
# ...           ...        ...          ...       ...  ... .. .. .. .. .. .. ..
# 55927   President     Barack      Obama's    recent  ...
# 55928       right        way      reacted     react  ...
# 55929     imports      major      trading  partners  ...
# 55930    delivery      giant      Windows        10  ...
# 55931  candidates    parties            U         S  ...
#
#       59 60                                           Headline
# 0            Lays Wreath Arlington National Cemetery Presid...
# 1            Haywood investment director business unit head...
# 2            Roubini NYU professor chairman Roubini Global ...
# 3            economy expanded marginally three months ended...
# 4            public spending continued boost economy Januar...
# ...   .. ..                                                ...
# 55927        Cuban leader Fidel Castro slammed President Ba...
# 55928        Obama caught predictable flak political right ...
# 55929        Trump wants put large tariffs imports major tr...
# 55930        business customers finally beginning take deli...
# 55931        WE know listening campaign rhetoric candidates...
#
# [55932 rows x 62 columns]

# %%
new_headline_words_df
# Out:
#                0         1           2            3          4          5  \
# 0          Obama      Lays      Wreath    Arlington   National   Cemetery
# 1            Tim   Haywood  investment     director   business       unit
# 2        Nouriel   Roubini         NYU    professor   chairman    Roubini
# 3      Finland's   economy    expanded   marginally      three     months
# 4        Tourism    public    spending    continued      boost    economy
# ...          ...       ...         ...          ...        ...        ...
# 55927    Retired     Cuban      leader        Fidel     Castro    slammed
# 55928  President     Obama      caught  predictable       flak  political
# 55929      While     Trump       wants          put      large    tariffs
# 55930  Microsoft  business   customers      finally  beginning       take
# 55931         AS        WE        know    listening   campaign   rhetoric
#
#                 6          7            8         9  ... 52 53 54 55 56 57 58  \
# 0       President     Barack        Obama      laid  ...
# 1            head      fixed       income       Gam  ...
# 2          Global  Economics     explains    global  ...
# 3           ended   December  contracting  previous  ...
# 4         January      light  contraction   private  ...
# ...           ...        ...          ...       ...  ... .. .. .. .. .. .. ..
# 55927   President     Barack      Obama's    recent  ...
# 55928       right        way      reacted     react  ...
# 55929     imports      major      trading  partners  ...
# 55930    delivery      giant      Windows        10  ...
# 55931  candidates    parties            U         S  ...
#
#       59 60                                           Headline
# 0            Lays Wreath Arlington National Cemetery Presid...
# 1            Haywood investment director business unit head...
# 2            Roubini NYU professor chairman Roubini Global ...
# 3            economy expanded marginally three months ended...
# 4            public spending continued boost economy Januar...
# ...   .. ..                                                ...
# 55927        Cuban leader Fidel Castro slammed President Ba...
# 55928        Obama caught predictable flak political right ...
# 55929        Trump wants put large tariffs imports major tr...
# 55930        business customers finally beginning take deli...
# 55931        WE know listening campaign rhetoric candidates...
#
# [55932 rows x 62 columns]

# %%
join=pd.DataFrame()
join['title_headline']=new_title_words_df['Title']+new_headline_words_df['Headline']

# %%
# import re
# s = "The   fox jumped   over    the log."
for sentence in join['title_headline']:
  re.sub("\s\s+" , " ", sentence)
  print(sentence)
# for word in join.iloc[2]:
#   print(word)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2016 UK economy top questions answered                  economic news since 2015 Autumn Statement bad disastrous Mr Osborne already said needs cut
# Growth Crisis                      Sri Lankan economy appears exist system evolve crisis Optimistic policymakers predicting country's
# adds Touch ID support Outlook iOS                  discriminate two offering many apps platforms One popular apps Outlook The email client
# polls Economy feeling betrayal                    Tuesday's contests expressed worries economy broad sense among Republicans party betrayed according early exit poll results
# highlights February's updates Office 365                   taken Office blog provide recap updates Office 365 February might thought well
# Opportunities Around China Weakening Economy                   slowdown Chinese economy forefront market discussion 2015
# announces quarterly dividend                     Wash March 15 2016 PRNewswire Microsoft Corp Tuesday announced board directors declared quarterly dividend 0 36 per share The dividend payable June 9 2016
# Is Sony's Incentive To Play Nice With Microsoft For PS4 Xbox             Microsoft MSFT 0 05 announced birth console utopia theory least They revealed Xbox One going
# Trump More Talented At Running For President Than                panelist MSNBC's Morning Joe Tuesday Halperin said Barack Obama strong third behind Bill Clinton Halperin
# announces developer preview new Bing Search APIs                 feedback developers partners customers Microsoft Bing team created next generation search APIs
# content Aussie economy UOB                    UOB Group noted minutes RBA's March meeting suggested Bank happy economy
# Manuel Miranda 'Hamilton' Creator Freestyles Obama                  single drum set Mr Obama held signs words common political process Constitution Obamacare Supreme Court
# announces quarterly dividend                     Wash March 15 2016 PRNewswire Microsoft Corp Tuesday announced board directors declared quarterly dividend 0 36 per share The dividend payable June 9 2016 shareholders record May 19 2016 The ex dividend date May 17 2016
# Obama Calls 'Vicious' 2016 Campaign 'Race                  Barack Obama speaks following meeting National Security Council Feb 25 2016 State Department Washington
# Obama Praises First Lady Michelle She Gorgeous                 joint interview dancer Misty Copeland Time magazine The White House talked young girls body image
# criticizes Trump violence rallies                    Barack Obama speaking Chief Missions Conference State Department Washington Monday March 14 2016
# hopes grow low carbon economy U K agreement                Alberta government signed agreement United Kingdom focuses creating jobs working together low carbon
# Cloud Scale Is Worth Price Amazon Google Microsoft                Microsoft Google combined nearly 26 billion capital expenditures 2015 Not went data center build
# UK economy changed must way measure                  capacity British economy build tanks guns planes And successful wartime direction production
# battle Manufacturing may sway swing state                  Ohio voters cast ballots Tuesday's presidential primary economy specifically manufacturing jobs front center
# Economy Rebound Following Slow Growth                   huge volatility Indian data boost emerging economies growth overall world output return towards trend like
# host expert meetings finance economy                   experts government officials discuss current economic financial problems well possible policy measures The talks could
# Microsoft testing TV DVR feature Xbox One                 Thurrott posted yesterday saying A source close Microsoft tells software giant internally testing TV DVR
# Gig Economy Crossroads Lawsuits Innovative                   benefits example could help gig economy workers transfer vacation time benefits rights job job work
# dismayed vulgarity violence campaign Tue 15 Mar 2016 PST               Barack Obama used unity luncheon Capitol Tuesday express concern nation political discourse protests escalated attacks
# Energy Producers Drop Dead                    know I'm starting think Obama Administration really like old fashioned hydrocarbon energy And since Federal
# destabilizing candor Middle East                    possible spent last weekend reading Jeffrey Goldberg's piece Atlantic decided President Obama right
# eases restrictions Cuba ahead trip                   Obama administration Tuesday loosened restrictions travel Cuba advancing cultural ties Communist island nation days ahead president's trip Havana As part series executive actions weaken decades old U S trade embargo Cuba
# Beauty pressures 'always harder' black women                  month President Barack Obama ballerina Misty Copeland sat TIME discuss rise respective fields
# New Way Analyze China's Deeply Flawed Economic Data                Krugman says quot economic data best viewed peculiarly boring genre science fiction Chinese data even
# offers preview WebAssembly support internal                   year Microsoft announced implementing WebAssembly new portable size load time efficient binary format suitable
# Today 03 15 2016                    Palestine Today service International Middle East Media Center www imemc org Tuesday March 15 2016
# hopes grow low carbon economy UK agreement                 Alberta government signed agreement United Kingdom focuses creating jobs working together low carbon
# stop' Obama blames campaign trail rhetoric violence                 S President Barack Obama listens question meeting U S Governors Association Thomson ReutersUS President
# rips Trump's 'vulgar divisive rhetoric aimed women                 Obama usually strikes joking tone talking 2016 Republican presidential race Not today I know I'm
# Obama Has A Single Coming Out Tomorrow                 DC MARCH 14 U S first lady Michelle Obama welcomes Broadway cast HAMILTON including Christopher Jackson
# Diplomat Ukraine Must Clean Up Corruption Liberalize Economy                rebuild consensus support aggressive measures clean corruption restore justice liberalize economy added
# abolishes last major restrictions US travel Cuba                 Barack Obama sent unmistakable message Americans Tuesday ahead historic trip Havana Cuba open business
# Speaker A time unity dangerous new Obama                 President Barack Obama gestures meeting American Jewish leaders photo credit OFFICIAL WHITE HOUSE PHOTO PETE
# India Relations Democratic Partners Economic Opportunity                  part however economic ties two countries kept pace growing strategic convergence With annual
# still potential CEOs                     yet another sign economy still room improvement Business Roundtable released survey Tuesday revealed
# 'Zombie companies' killing economy                    King HSBC's senior economic adviser prescriptions cure problem fiscal stimulus increasing world trade one suggestion
# denounces rise 'vulgar divisive' politics Trump                  worth asking us may done contribute vicious atmosphere politics Obama told
# adds former Nokia CEO Stephen Elop leadership team                today revealed recruited former Nokia CEO oversaw sell handset business Microsoft joining software vendor head devices group
# vicious tone violence campaign trail stop                  President Barack Obama said Tuesday dismayed happening U S presidential campaign trail reference Republican front runner Donald Trump called leaders reject violence clean tone race We heard vulgar divisive rhetoric aimed women minorities Americans look like us pray like us vote
# build capacity impact Nigeria market Microsoft MD                 impact Microsoft Nigerian economy e evidenced areas employment support start ups education building local
# condemns violence presidential campaign trail video                  Barack Obama took opportunity press event Capitol Hill Washington Tuesday condemn violence
# made even easier travel Cuba                   lead historic trip Cuba later month President Barack Obama announced ease another set restrictions
# Hints Trump Tarnishes America's Brand                   Barack Obama called Americans reject violence Donald Trump's rallies mention Republican
# knocks 'vulgar divisive' presidential campaign                   President Barack Obama lamented vulgar divisive presidential campaign Tuesday saying GOP presidential
# Talk Is Cheap For Obama Not OPEC                 21EUR President Obama's pledge open Atlantic Coast oil drilling little like promising become brain surgeon
# offshore drilling plan mostly win environmentalists                  Obama shown little interest gambling environmental legacy final year office Rather slow Paris climate change
# Obama Enlists Missy Elliott Janelle Mon e Zendaya More               First Lady Michelle Obama give opening keynote SXSW Music She'll talk Let Girls Learn initiative
# Obama issued dire warning                    appearance annual Friends Ireland reception Capitol Hill President Obama delivered stirring condemnation climate
# Trump                       2004 Thomas Frank scored hit What's Matter Kansas lamenting voters state failed recognize economic
# set announce Supreme Court nominee                   Reuters President Barack Obama announce nominee U S Supreme Court 11 EDT 1500 GMT Wednesday said statement released White House setting stage political showdown Republicans control Senate
# sees strong growth despite global risks                  Irish economy face slew threats facing world economy continue post strong growth 2017 ESRI think tank predicted
# 'cocktail threats' stir shake economy                   world economy may face dangerous cocktail new threats George Osborne colourfully declared January That
# idea election would fix racism quot I one                able see relate successful people look like crucial said President Obama conversation ballerina Misty
# May Counter Trump Immigrants With Supreme Court Pick                Barack Obama's U S Supreme Court nomination may prove sharpest repudiation yet anti immigrant sentiment stirred
# Obama doctrine Israel                     President Barack Obama Prime Minister Benjamin Netanyahu hold meeting Oval Office White House photo credit AFP
# joins states bid close 'diaper divide'                  Barack Obama wants change nation's quot diaper divide quot helping low income families cope cost diapers At
# deeply dismayed 'vulgar' presidential campaign                   S President Barack Obama delivers remarks divisiveness U S politics annual Friends Ireland Luncheon U S Capitol
# Obama hails 'significant progress' Irish economy                  Taoiseach Enda Kenny met US president Barack Obama White House part day long programme events
# amp Malia Obama Wore 40K Dresses To Dinner                Malia Obama moved J Crew RadarOnline com learned teen siblings recently sported dresses dinner
# Criticizes Protesters' 'Misguided Attempts Shut Down                  Obama delivered remarks earlier today criticized concerning rhetoric coming Donald Trump's mouth
# Before Critical Vote In 5 States Obama Denounces Trump               speaking St Patrick's Day luncheon Capitol President Obama strongly denounced violence rhetoric used
# Marsudi assures Indonesian mission Palestine accomplished                  Foreign Minister Retno Marsudi right took picture opening Indonesian Honorary Consulate Palestine
# We've Heard quot Silence quot Divisive Language Violence At               Obama denounced Republican presidential primary race Friends Ireland lunch hosted House Speaker Paul Ryan
# Ankara Bombing Fears Loom Over Turkey's Economic Future                People take trip telpher Yenimahalle district Turkey's capital Ankara sunset Oct 16 2015 Photo Ahmet
# suffers Microsoft Cameron's Apple                    Osborne's battle become Conservative leader may well tougher battle faces Labour opposition
# Urges Rejection Violence Campaign Rallies                   President Obama Tuesday warned violent scenes playing rallies Donald J Trump threaten tarnish
# War 4 beta release date Microsoft reveal Xbox One launch              month see launch Microsoft's global Versus multiplayer beta run exclusively Xbox One The Gears Wars 4
# Official Warns 'Damage' Nuclear Deal Fails Boost Economy                nuclear deal real serious opening Iran economic relations If happen tangible results follow
# With Struggling Economies Aren't Feeling The Bern                 improving national economy black unemployment rate still remains 10 percent seven states Alabama California
# swipes GOP race 'vicious atmosphere'                   Barack Obama decried called quot vicious atmosphere quot national politics presidential campaign speech Tuesday included several swipes Republican front runner Donald Trump
# Sisters' captures challenges success female racers                  movie follows four young women female manager drive autocross series organized The Palestinian Motor Sport
# Are Shifting Within Economy                    four main drivers economic activity energy technology debt demographics I discussed column quot Understanding
# Kuwait host 'Innovation Bazaar'                    Microsoft Kuwait showcase latest innovative solutions Microsoft Innovation Bazaar Sunday 20th March 2016
# Republicans agree Economy top issue                   Republican Democratic primary voters agree economy key issue 2016 presidential race according exit polls interviews conducted Tuesday
# open tech promises switch hardware independence                  latest Microsoft open tech takes brains data center networking proprietary switches places hardware agnostic software
# Obama Doctrine Passive Messianism                    years ago The Atlantic published article mine entitled A Black Clinton I predicted certain Barack Obama
# Founder Obama Sex Tape Would Not Be Newsworthy                Founder Obama Sex Tape Would Not Be Newsworthy stance Obama loving couple footage news worthy
# abdicated responsibility world economy                    economic news prompts market tantrums raises prospect central banks tightening policy But even twisted logic appears
# Is Letting Xbox Playstation Gamers Play Each Other                enabled developers support cross network play Xbox Live network giving Xbox Playstation PC gamers chance
# economy expected reach 44 billion 2020                  dollar spent medical recreational marijuana retail level leads extra 3 economy In four years report
# files pay selfie patent Microsoft's face authentication languishes                filed patent Tuesday anticipates future users simply smile camera authorize online purchase It begs question Why Microsoft already
# calls 'cycle' campaign trail animosity end                  Barack Obama took occasion typically apolitical event Tuesday share dismay recent violence animosity
# Microsoft Mozilla preview WebAssembly browsers                   previews run internal Microsoft Edge browser build Mozilla's Firefox Google's Chrome Work WebAssembly also
# Focuses On Integration With Microsoft Skype Business Tools                communication specialist Polycom's integration solutions built specifically Office 365 Skype Business
# world celebrates Palestinian poet's 75th birthday                  poet Mahmoud Darwish born March 13 1941 Galilee village al Birweh Darwish's birthplace
# exec Frustrated customers lining ditch Oracle                  Microsoft Cloud Enterprise Corporate VP Takeshi Numoto says following announcement customers chomping bit give
# economy hangs thread                     budget presented Finance Minister Parminder Singh Dhindsa unmistakably indicated state's economy hanging
# The Lone Ranger                     1993 Oslo accord Palestinians Israel Palestinian Authority wanted Israel evacuate settlers
# Obama Condemn Campaign Trail Violence                   House Paul Ryan President Barack Obama condemned rhetoric violence erupted Republican
# Obama 'We political debates without turning                  Obama suddenly much say state political discourse United States On Friday offered assessment
# Chase appoints former Obama advisor lead                  Wheeler former economic advisor President Obama joined JPMorgan Chase managing director leading fintech
# admits failed discourage radicalism among Muslims Newspaper DAWN COM               President Barack Obama talks guests Iftar dinner celebrating Ramadan State Dining Room White House Washington AFP File
# hits 16 race violence vulgar divisive rhetoric women minorities               browser needs Javascript use site U S President Barack Obama left House Speaker Paul Ryan greet one another Obama's remarks Ireland's Prime Minister Enda Kenny annual Friends Ireland Luncheon U S Capitol Washington Tuesday
# Ithaca's startup economy Rev wins award                  right Tom Schryver Rev accepts Economic Development Project Year Award Ithaca Mayor Svante Myrick '09 center
# continues Linux lovefest open source network                  last week Open Compute Project Summit Microsoft announced SONiC set open source software components used
# Launches Haven OnDemand On Microsoft Azure                  two years beta Hewlett Packard Enterprise HPE launched machine learning service solution Microsoft Azure
# shows HoloLens Actiongrams watching TV zombie pal                 developers access Microsoft HoloLens there's telling augmented reality headset available consumers But stopped Microsoft showing merits Actiongram app HoloLens
# House Loosens Restrictions With Cuba Ahead Of Obama Visit               President Obama prepares historic visit Cuba next week administration taking additional steps relax restrictions travel
# Obama accuses Donald Trump scaring America's children                 Barack Obama launched outspoken attack Donald Trump last night accusing billionaire damaging America's image
# opening world 'Minecraft' Gear VR                   Oculus Rift virtual reality platform getting piece Minecraft's pie Today event held GDC 2016 Microsoft
# Rolling Out New Office 365 Reporting Portal                 described new quot reporting portal quot that's rolling early today Office 365 subscribers This reporting portal shows user
# One Judge Obama's Supreme Court Short List Could Have               judges President Barack Obama's short list Supreme Court could draw fire right left
# Hamilton As US Economic Architect                   America get rich quickly It's question heart economics one broad definition study
# turmoil dragging economy Itaú's Setubal says                  Guillermo Parra Bernal SAO PAULO Reuters Brazil's escalating political turmoil dragging economy mire government looks unable implement much needed reforms resuscitate activity head nation's biggest private sector bank said late Tuesday As President Dilma Rousseff's administration wrestles fallout corruption probe
# Trump Motivated Run For President After Obama Ridiculed                shows President Obama mocking Donald Trump speech 2011 White House Correspondents' Dinner
# Obama Enlists Missy Elliott Zendaya New Song                 time Michelle Obama's keynote address South Southwest Austin First Lady assembled star empowerment
# Gulf Still Open Offshore Drilling Obama's 5 Year                Gulf Still Open Offshore Drilling Obama's 5 Year Draft Plan We pleased President Obama responded concerns
# readies Zika prevention                     Tx March 15 2016 The City Palestine working combat spread Zika virus summer approaches
# Misuse Special Operations Forces Has Led Larger                 S Navy SEALs jump CH 46E Sea Knight training near Fort Pickett U S Navy photo Petty Officer 2nd Class Meranda
# Deconstruct President Obama's Bi Partisan Taco Order SXSW                receipt Lydia Pantazes TV reporter Austin area tweeted Obama also got green chili pork slow roasted pork
# continues Linux lovefest open source network software SONiC                open source binge lately It brought Red Hat Enterprise Linux Azure public cloud last year Redmond database gurus opened SQL Server run Linux earlier month
# spray mosquitos effort prevent Zika virus                  city Palestine working combat spread Zika virus The city soon begin spray mosquitoes residents
# cut growth forecast Singapore economy 1 9                 polled Monetary Authority Singapore MAS cutting growth forecast economy 2016 2 2 percent 1 9 percent central bank's latest quarterly survey revealed Wednesday 16 March
# cut forecast Singapore economy 1 9                  polled Monetary Authority Singapore MAS cutting growth forecast economy 2016 2 2 percent 1 9 percent central bank's latest quarterly survey revealed Wednesday 16 March quot As reflected mean probability distribution likely outcome Singapore economy grow 1 0 1 9 percent year
# President Obama adds 16 parishes federal disaster                 Abraham M D R Alto said Tuesday President Barack Obama granted request declare 16 additional parishes federal
# turmoil dragging economy Itaú's Setubal says                  PAULO Reuters Brazil's escalating political turmoil dragging economy mire government looks unable implement much needed reforms resuscitate activity head nation's biggest private sector bank said late Tuesday
# Blasio Makes Bipartisan Push Reverse Obama Terror Cuts                Bill de Blasio testifies House Homeland Security Emergency Preparedness Subcommittee Washington D C Tuesday
# Obama AND Top Republicans bash Donald Trump                 also seemed condemn left wing efforts stifle Trump quasi riot erupted Obama's adopted hometown Chicago
# abolishes last major restrictions US travel Cuba                 AP President Barack Obama sent unmistakable message Americans Tuesday ahead historic trip Havana Cuba open
# cut 2016 growth forecast Singapore economy 1 9 MAS survey              economy expected grow 1 9 per cent year according median forecast analysts quarterly survey Monetary Authority Singapore Analysts forecast growth 2 2 per cent previous survey
# turmoil dragging economy Itaú's Setubal says                  escalating political turmoil dragging economy mire government looks unable implement much needed reforms resuscitate activity head nation's biggest private sector bank said late Tuesday
# Workers High Demand Economy Improves                   reports federal state labor departments show Maine's economy sustained upswing Unemployment dropped
# changes mind invites startup planning                   changed mind asking startup Okta come back sponsor Microsoft's upcoming Ignite tech conference
# Responds Microsoft's Invite Connect Xbox One PS4                 custodian directly acknowledge Microsoft's open invitation suggests open minded partnerships
# Tournament expected bring flood visitors boost local                 major event terms economic development said Scott Dupree Greater Raleigh Sports Alliance executive director Dupree said
# delivers stern message Trump                    Obama delivered serious message Republican presidential hopeful Donald Trump light hearted Friends Ireland
# hopes grow low carbon economy UK agreement                 The Alberta government signed agreement United Kingdom focuses creating jobs working together
# row World T20 women fly economy men business                world's best women cricketers flying low comes travel arrangements get upgrade according New
# investments key rural Montana's economy                   Rittal president Montana Economic Development Association What outlook Montana's rural economy 2016
# focus firing economy                     Lin led finance ministry 2002 2006 He also drafted economic proposals helped propel Ms Tsai's DPP election
# benefit Chinese learn spend                    China's economy overdone Australia set benefit hugely country's growing middle class learns spend rather save leading economist says Former ANZ chief economist Warren Hogan told tourism conference Sydney China's communist government successful far managing transition service led economy next step
# benefit Chinese learn spend                    China's economy overdone Australia set benefit hugely country's growing middle class learns spend rather save leading economist says Former ANZ chief economist Warren Hogan told tourism conference Sydney China's communist government successful far managing transition service led economy next step
# Mil Officials Obama's National Security Council Is Full Of               President Barack Obama flanked US Secretary State John Kerry L US Defense Secretary Ashton Carter arrive speak
# Devices Stephen Elop joins Telstra                   Microsoft Devices Group executive vice president Stephen Elop joined Telstra newly created role Elop company technology innovation strategy group executive responsible leading Telstra strategic direction
# nominates McKeesport native federal bench                   A member U S Attorney's Office Western Pennsylvania nominated President Barack Obama serve
# explores banking contribution state economy                   James Hughes Rutgers' Bloustein School addresses attendees Economic Impact Assessment Hughes reported quot The
# Responds Microsoft Opening Xbox Live's Borders Other                 recently announced plans invite apocalypse rather allow developers support cross network play games
# close naming Supreme Court nominee                   Barack Obama's team finished critical work vetting potential candidates Supreme Court nomination decision President could announced early Wednesday several sources tell CNN The formal process sc
# close naming Supreme Court nominee                   Barack Obama's team finished critical work vetting potential candidates Supreme Court nomination decision President could announced early Wednesday several sources tell CNN
# hopeful tale China's old new economies Bangkok Post                air Chinese economy IIF G20 conference Shanghai late last month The annual forum set stage
# Energy Obama takes Atlantic drilling table                  DRILL BABY President Obama took possibility Atlantic offshore drilling table Tuesday reversing earlier proposal
# Palestine                       widely touted goal two state solution Israel Palestine would agree line demarcation peacefully recognize
# African Republic economy grows 5 pct 2015 best years               2014 growth 1 percent 2013 economy contracted 37 percent quot Since 2000 Central African Republic experienced
# economy 'hard landing' premier                    economy quot hard landing quot Premier Li Keqiang said Wednesday despite widespread fears government difficulty managing slowing economic growth quot We long term confidence Chinese economy confidence without foundation quot Li told year annual press conference end annual session Communist controlled
# super superdelegate President Obama                    would President Obama one time U S senator Land Lincoln also served superdelegate state
# Phone's Failure Gifts Microsoft A Killer Surface Phone                Windows Phone distant memory Microsoft effectively left mass market smartphone hardware game That mean
# electorate hampers efforts mend 'slow puncture' economy                 Mike Dolan LONDON Reuters The combination slow growth world shrinking policy options splintered political voting patterns fostered stifling global economy critical juncture Preying minds financial markets past year fear there's big economic policy bazooka fire another cyclical downturn recession With major
# Fractured electorate hampers efforts mend 'slow puncture' economy                combination slow growth world shrinking policy options splintered political voting patterns fostered stifling global economy critical juncture Preying minds financial markets past year fear there's big economic policy bazooka fire another cyclical downturn recession With major central banks maxed near
# Obama Referendum                      Obama week washed hands tone politics somebody else president past seven years
# Obama Cited Batman The Dark Knight In White House               recent interview President Barack Obama via The Atlantic revealed White House strategy meetings advisors
# build capacity impact Nigeria market Microsoft MD                 impact Microsoft Nigerian economy e evidenced areas employment support start ups education building local
# pay selfie patent authentication model                   begs question Why Microsoft already Amazon's patent question simply uses image authentication technology
# electorate hampers efforts mend 'slow puncture' economy                 combination slow growth world shrinking policy options splintered political voting patterns fostered stifling global economy critical juncture
# economy 'hard landing' premier                    economy quot hard landing quot Premier Li Keqiang said Wednesday despite widespread fears government difficulty managing slowing economic growth quot We long term confidence Chinese economy confidence without foundation quot Li told year annual press conference end annual session Communist controlled
# Tuesday 3 exit polls Economic worries feeling GOP                CNN Voters Tuesday's contests expressed worries economy broad sense among Republicans party
# la Pr sidence du Faso La Palestine veut partager son              pr sident du Faso Roch Marc Christian Kabor u en audience ce mardi 15 mars 2016 au palais de Kosyam l'Ambassadeur de l'Etat
# energy emissions stall even economic growth rises                 related carbon emissions stayed flat second consecutive year last year new data show even though global economy kept
# Ellison explains Microsoft Amazon going                   dig offer requires customers sign Microsoft's cloud database well version extended warranty known Software
# Afghan Dilemma To Bomb Not Bomb                  Taliban's growing military might posing thorny strategic question President Barack Obama took office promising end
# Highlights Asia's Advancing Role Global Economy                  ray hope global economic recovery added Indian Prime Minister Narenda Modi The twenty first century
# Mission Palestine Accomplished Minister Retno                   Foreign Minister Retno Marsudi right inaugurates Indonesian Honorary Consul Palestine Maha Abu Susheh Amman
# London Savages Obama's Anti Brexit Intervention                  Mayor Boris Johnson C delivers statement media regarding position forthcoming EU referendum outside home
# Carson's Latest Article The Economy Breathtakingly Stupid                 one sum Republican Party's general stance economics would go something like Debt bad government bad
# announces quarterly dividend                     Wash March 15 2016 PRNewswire Microsoft Corp Tuesday announced board directors declared quarterly
# blacks worse Obama like Trump says                  unemployment rate black teens well blacks age 16 24 dropped half high point Obama
# Candidates Setting Bad Examples Kids                   COUNTY The race president yet President Obama calling candidates stop vulgar start
# multi billion dollar man Horacio Gutierrez departs                 current general counsel former head IP Horacio Gutierrez one major players company's lucrative
# Are Fleeing Oracle Into Arms Microsoft's SQL                 remarkable strategic shift Microsoft NASDAQ MSFT announced earlier month launching new version popular SQL
# Kantor knocking SARB's door worry economy                  says South Africa's monetary policy instead focus limiting damage higher interest rates caused economy
# electorate hampers efforts mend 'slow puncture' economy                 minds financial markets past year fear there's big economic policy bazooka fire another cyclical
# electorate hampers efforts mend 'slow puncture' economy                 minds financial markets past year fear there's big economic policy bazooka fire another cyclical downturn
# Hires Microsoft's Horacio Gutierrez General Counsel                  Gutierrez top lawyer Microsoft leaving company join streaming service Spotify similar role Spotify says Gutierrez
# expanding cloud service availability Germany                   making available preview select Azure cloud services previously announced German Canadian Azure regions
# say Embargo solution Palestine Israel                   pressure President Joko Jokowi Widodo center Palestine President Mahmoud Abbas left Organization Islamic
# knocks 'vulgar divisive' presidential campaign                   CNN President Barack Obama lamented quot vulgar divisive quot presidential campaign Tuesday saying GOP presidential
# Palestinian poet still sparks controversy Israel                  13 marked 75th anniversary Palestinian poet Mahmoud Darwish passed away Aug 9 2008 A special event held
# real cause Trump Obama                    McWhorter teaches linguistics American studies philosophy music history Columbia University author quot The
# Bans Palestinian Products Inside Occupied Palestinian Territory                 Palestinian companies warned financial losses Israeli occupation forces banned products marketed occupied
# picks Kansas win men's NCAA basketball tournament                 Barack Obama's tournament bracket revealed ESPN's quot SportsCenter quot Wednesday morning final bracket president
# cancels visa Palestinian activist anti settlement lawsuit                 Tamimi Palestinian activist led weekly popular protests Nabi Saleh village threatened Israeli engorgement
# Minecraft Is Helping Microsoft Advance AI                  turns Microsoft purchased game inherited loyal community sprouted around software giant also ended
# boys soccer team remains No 1 state poll                PARK Calif The Palestine boys soccer team remained No 1 MaxPreps Texas Class 4A state poll released
# mayoral candidates spar city's economy                   seven candidates took stage 6 30 p Tuesday highly anticipated debate city's economy They began opening
# House Obama would sign FOIA bill                  Barack Obama would sign Freedom Information Act reform bill Senate passed Tuesday reaches desk form
# Facts You Probably Didn't Know About Microsoft                 Microsoft everywhere From origins super hot startup 1970s taking world 1990s current reinvention CEO Satya Nadella Microsoft long storied history right alongside PC But much really know company More
# Shift Obama Won't Open Southeast Atlantic Coast Drilling                Obama administration unveiled proposal last January open southeastern Atlantic coast oil gas drilling first time
# 16 Mar 2016                     March 16 2016 WAFA The Palestine Meteorological Department warned low visibility Wednesday amid increasingly cloudy rainy skies
# judicial nominees can't even get 'Borked' Senate                 anyone surprised judicial wars went nuclear even President Obama chose Supreme Court nominee
# Warren Explains How Michelle Obama's 'This Is My Girls               It's kind like 'We Are World' meets 'Lady Marmalade' strong voices strong women quot songwriter tells Billboard
# Wilmington mayoral debate economy                    can't view video click watch debate STORY Wilmington mayoral candidates spar city's economy Read Share
# hard landing Chinese economy premier                   Li Keqiang says Chinese economy hard landing despite widespread fears government difficulty managing slowing economic growth
# nominates Merrick Garland Supreme Court sets Senate showdown                Obama named federal appeals judge Merrick Garland Wednesday pick succeed Antonin Scalia U S Supreme Court setting showdown Republicans vowed block choice
# 16 Mar 2016                     March 16 2016 WAFA Secretary General Palestine Liberation Organization PLO Saeb Erekat denounced Tuesday Israeli authorities decision declare 2 342 dunums near Jericho state land
# world fuel economy figures Peugeot Citroen                  Peugeot Citroen used recent Geneva motor show unveil new cars new system judging fuel economy
# Expands Settlements In Occupied West Bank Seizes Large Tracts Near Jericho             Israeli government seized large tracts land occupied West Bank near Dead Sea Palestinian city Jericho Israeli nonprofit Peace Now tracks spread settlements region Israeli Army Radio reported Tuesday The seizure 579 acres 234 hectares land one largest land confiscations West Bank recent years
# Economy The Sum Of The Parts INFOGRAPHIC                 vast countries United States Canada incredible diversity within borders Every part country
# invites Todd Hirsch give economy speech                  Rotary Club Cochrane welcoming ATB's Financial Chief Economist Todd Hirsch evening's guest speaker roast beef
# African Republic economy grows 5 pct 2015 best years               African Republic's economy grew 4 9 percent last year biggest growth since 2000 country tried emerge years conflict deputy governor Bank Central African States BEAC said Tuesday In interview national radio Mahamat Tahir Ahmed said increased activity sectors economy helped boost growth years poor performance
# slams 'vulgar divisive' primaries campaign                   S President Barack Obama warned fellow politicians 2016 presidential campaign trail damaging U S ' reputation abroad
# slams 'vulgar divisive' campaign                    S President Barack Obama warned fellow politicians 2016 presidential campaign trail damaging U S ' reputation abroad
# Confiscates Large Tract Palestine Land West Bank                 announced Army Radio today appropriated large tract Palestinian land occupied West Bank confiscating
# Inc Slashes Wage Increases Abe Fails Boost Economy                major companies giving lower wage increases next fiscal year Prime Minister Shinzo Abe efforts boost economy falter
# Premier Li says confident economy vows hard landing                Premier Li Keqiang defended government's economic policies Wednesday vowing would mass layoffs hard landing world's second largest economy even government presses ahead painful reforms While conceding downward pressure increasing Li top officials annual meeting parliament month repeatedly tried
# Azure close several key government certifications                  announced Tuesday track land series key certifications continuing effort provide cloud services U S government
# Premier Li says confident economy vows hard landing                Jason Subler Kevin Yao BEIJING Reuters China's Premier Li Keqiang defended government's economic policies Wednesday vowing would mass layoffs hard landing world's second largest economy even government presses ahead painful reforms While conceding downward pressure increasing Li top officials annual meeting
# ...
# quick look Microsoft's Translator extension Edge Windows                 introduced extensions Microsoft Edge users Windows 10 Preview time ago But three extensions currently
# announce steps fight heroin opioid epidemic                  US President Barack Obama set announce steps Tuesday expand treatment people addicted heroin prescription painkillers White House said Obama travel summit Atlanta meet addicts recovery family members medical professionals law enforcement officials talk opioid epidemic become issue 2016
# Administration Defends Limit Power Plant Carbon                  The Obama administration Monday offered comprehensive legal defense signature climate change regulation
# focus WA cabinet reshuffle                    WA economy struggles diversify beyond resources cabinet reshuffle shows state government pins hopes agriculture tourism
# economy bigger thought                     informal townships economy much larger previously thought doubled since 2010 findings study one
# Lula Calls Tax Breaks Boost Economy                  Brazilian President Luiz Inacio Lula da Silva called tax breaks consumer credit Monday effort spur economic
# Microsoft Google Which Tech Stock Is Winning                 Microsoft's Azure leads pack comes data center regions boasting 20 right Google trailing far behind 4
# racist hijacking Microsoft chatbot shows internet teems hate                apologetic AI Twitter feed started spewing bigoted tweets incident simply highlights toxic often antisemitic side social media It took two tweets internet troll going name Ryan Poole get Tay become antisemitic Tay chatbot set Microsoft 23 March computer generated personality simulate online
# relentless pursuit stake Yahoo's core business                  one said willing quot lend significant financing quot buyout firms interested bidding Yahoo according Re code
# meet South Korea Japan leaders Thursday White                 President Barack Obama week meet Japanese Prime Minister Shinzo Abe South Korean President Park Geun Hye
# Timor Leste                      Cup Qualification AFC Follow Football match Palestine Timor Leste live Eurosport The match starts 16 00
# Fancy Catering amp Bakery brings home baked charm                walking Old Magnolia Mercantile downtown Palestine one expects see beautiful old antique pie safes shiny porcelain topped
# Canada may start revealing view federal budget's                 Doyle BloombergThe Bank Canada Ottawa's economic forecasts stimulus plans hand governor Stephen Poloz
# Microsoft hearting Linux amp Open Source                  time Microsoft totally Open Source software considered many including Linux opponents
# remains 'blue' February council                    Taiwan The economic monitoring indicator flashed quot blue quot signal February indicate recession ninth month row
# Jopwell Fill Crucial Gap Information Economy                  well documented African Americans Latinos racial minorities underrepresented many fields including tech
# China Not Just Economy Political Resolve                  economic collapse longer seems imminent The Wall Street hedge funds bet Chinese currency taken heavy
# created device lets 'teleport' anywhere world                  quot holoportation quot device could radically change keep touch friends family afar Holoportation new type
# Appropriate proceed cautiously                     Federal Reserve proceed caution adjusting policy Chair Janet Yellen said Tuesday acknowledging economic
# CFOs uncertain economy                     CFOs think probability 25 country's economy fall recession end year Almost three quarters
# Obama's quot Open Door quot Policy With Syrian Refugees quot Could             Trump talks National Enquirer story Ted Cruz President Obama welcoming Syrian refugees NATO Brussels
# Isn't Fan UN's Pro Palestinian Choice Human                 gave presentation conference 2009 topic unified Palestinian Israeli state tagline event quot country
# Obama economy helped create Trump                   anything Republicans done enough blame President Obama sick American economy Nicholas Confessore writes
# PA denying Gazans passports                    CITY Gaza Strip Palestinian police Gaza accompanied State Audit Administrative Control Bureau SAACB raided
# shows Israeli soldier greeting far right activist killing                Israeli soldier shot dead wounded Palestinian attacker recorded shaking hands far right Jewish activist victim's
# scandal Canadian twist New human rights rapporteur                 awkwardly named position United Nations Special Rapporteur situation human rights Palestinian territories occupied
# asks UN probe Israel killings                   Palestinian Authority asked United Nations yesterday investigate extrajudicial killings Israeli occupation forces The request came last week's
# Easter Bunny highlight Obama's final egg roll                 first lady Michelle Obama hosted 35 000 guests South Lawn 138th annual event Obama said one
# Obama Calls Journalists Hold Candidates                   President Barack Obama Monday bemoaned political environment surrounding year's presidential
# Park Abe discuss North Korea Thursday                  said Xi push Obama resume talks North Korean Obama Park Abe last met trilaterally sidelines
# pans 'splintered' media                     Obama Monday criticized splintered media creating different world different facts based conservative
# Obama Chides Media For 2016 Election Coverage                 Obama delivered stern rebuke media role 2016 campaign sees holding candidates
# Studiotime Retool The Sharing Economy For The                 music news usually hear physical goods financial rewards accompany end beginning creative
# anti discrimination law economy                    NC WNCT North Carolina's new law House Bill 2 gaining lot opposition big businesses across country
# working feature Redstone that's similar Apple's                  Microsoft kicks annual developer conference Build Wednesday one big focuses Continuum feature turns
# high flying equity market recovery might already overcooked                Brazilian economy rescued change leadership staggering equity market recovery probably overdone
# high flying equity market recovery might already overcooked                Brazilian economy rescued change leadership staggering equity market recovery probably overdone
# economy set transformation                     past 10 years 80 territorial local economies TLAs grew faster Horowhenua District also ranked 62 66 TLAs
# Historian Obama's Just The Latest President To Rely                Obama's time White House point measured months according presidential historian Douglas Brinkley
# Castro Criticizes Barack Obama's Efforts Change Cuba                 CITY Fidel Castro former president Cuba offered critical response Monday President Obama's recent visit
# aims educate Palestinian history                    Razaq says quot When people hear Palestine kind shut sometimes They think complicated there's much
# Is Obama Squared                     Trump Barack Obama squared Not matter rhetorical style president glib grammatical developer
# eyes Y5 tril stimulus steps support economy                 government ruling parties consider compiling economic stimulus measures worth 5 trillion yen 44 billion prevent
# tourism economy struggling                     tourism economy struggling Suicide bombings Istanbul row Kremlin hard times Russian middle class
# tourism economy struggling                     bombings Istanbul row Kremlin hard times Russian middle class factors spell trouble Turkey's
# address nation growing opioid problem                   AP The Obama administration issue proposed rule Tuesday aims increase medication based treatment tens thousands people addicted opioids The proposed rule along commitment 60 medical schools heighten training prescribing opioids coincide President Barack Obama visit Atlanta
# Addressing Mental Illness Goes Beyond Obamacare                  opioid mental health crises Obama administration pushing Medicaid expansion solution A woman sits corner
# address nation's growing opioid problem                   The Obama administration issue proposed rule Tuesday aims increase medication based treatment tens thousands people addicted opioids
# gig economy really Uber economy                   quot sharing economy quot quot app economy quot quot perma lancer economy Still jobs small slice U S economy likely less 1
# seeing China leader South China Sea tensions rise                AP President Barack Obama meeting Asian leaders Washington week fears grow long smoldering tensions Korean Peninsula South China Sea risk flaring conflict
# seeing China leader South China Sea tensions rise                AP President Barack Obama meeting Asian leaders Washington week fears grow long smoldering tensions Korean Peninsula South China Sea risk flaring conflict
# sector confidence UK economy drops sharply                  China's economic slowdown among reasons UK's financial sector's dwindling confidence Photograph Rolex Dela
# warns threats Irish economic growth                   employers lobby group expects economic growth 4 6 per cent year 3 9 per cent 2017 But warned uncertainty
# Monday 'Holoportation ' Racist Tay Chatbot Gets Shut                Monday takes look back past week news related Microsoft This week Microsoft Monday includes details
# expect Microsoft Build week                    annual Build developer conference kicks Wednesday Moscone Center San Francisco streamed online
# THE LINES                      Obama reaffirmed determination remain war country leads Jan 20 2017 admitting 100 000 predominantly
# What Barack Obama really thinks world leaders                 remarkable insight President Obama's approach foreign policy based many hours conversations president
# Democrats Call For Vote On Obama's Supreme Court                Committee hearings began 1916 every pending Supreme Court nominee received hearing except 9 nominees
# 'perfect storm' brewing important part UK                  perfect storm fears state world economy Britain's place EU market volatility gathering Britain's dominant
# economy rebounding terrorist attacks                    host Lizzie O'Leary talked BBC reporter Dan Johnson Brussels residents Belgian capital returning
# taught Obama Garland talks Supreme Court                  taught Garland Obama students prestigious school He continues advise White House legal issues
# Obama's guide world leaders'                    20 000 word essay Mr Obama's foreign policy April's issue Atlantic magazine already picked insights
# address nation's growing opioid problem                   AP quot The Obama administration issue proposed rule Tuesday aims increase medication based treatment tens thousands people addicted opioids The proposed rule along commitment 60
# WARNING Obama vows tackle North Korea threat                 Obama meet presidents South Korea Japan discuss North Korea's nuclear programme amid fears Kim Jong un
# welcomes Easter Egg Roll guests GIFs                  CNN President Barack Obama first lady Michelle Obama welcomed guests White House annual Easter Egg
# tackles heroin prescription drugs addiction new                  Barack Obama Tuesday announce mutli part program combat problem including new efforts medical schools
# welcomes Easter Egg Roll guests GIFs                  CNN President Barack Obama first lady Michelle Obama welcomed guests White House annual Easter Egg
# Job Seekers Optimistic About Gig Economy Fear Robots                growing demand gig economy threat job automation tighter labor market 44 percent identified job seekers said
# calls journalists hold candidates higher standard                  President Obama Monday bemoaned political environment surrounding presidential elections called journalists hold candidates higher standard
# Castro Lashes Out Obama After Cuba Visit                 Cuban leader Fidel Castro slammed President Barack Obama's recent visit Caribbean island warning countrymen beware
# CRISP Obama's strategic reaction Brussels                   Obama caught predictable flak political right way reacted react terrorist bombings Brussels last week
# Trump's 45 Percent Tariffs Are Bad Try Obama's 10000               Trump wants put large tariffs imports major trading partners President Obama actively pushing far
# finally releases giant Surface                    business customers finally beginning take delivery giant Windows 10 powered digital whiteboard
# sunshine US economy                     WE know listening campaign rhetoric candidates parties U S economy disastrous shape China

# %%
for word in join.iloc[2]:
  print(word)
# Out:
# Roubini Global Economy Not Back 2008                  Roubini NYU professor chairman Roubini Global Economics explains global economy facing conditions

# %%
# df["Period"] = df[["Title", "Headline"]].apply("-".join, axis=1)

# %%
# X_tfidf = tfidf_vect.fit_transform(join['title_headline'])
# # print(X_tfidf.shape)
# X_tfidf
# print(tfidf_vect.get_feature_names())
# X_tfidf = pd.DataFrame(X_tfidf.toarray())
# X_tfidf

# %%
title_headline_labels = list()
for i in range(len(sentiment_headlines)):
    if(sentiment_headlines[i]+sentiment_titles[i] < 0):
        title_headline_labels.append(-1)
    elif(sentiment_headlines[i]+sentiment_titles[i] > 0):
        title_headline_labels.append(1)
    else:
        title_headline_labels.append(0)
pd.DataFrame(title_headline_labels)
sentiment_title_headlines_df = pd.DataFrame(title_headline_labels)

# %%
sentiment_title_headlines_df.shape
# Out:
# (55932, 1)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(join['title_headline'])
# X_test = vectorizer.transform(join['title_headline'])
# X= X_tfidf
y = sentiment_title_headlines_df

# %%
X
# Out:
# <55932x41176 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1102023 stored elements in Compressed Sparse Row format>

# %%
y
# Out:
#        0
# 0     -1
# 1      1
# 2     -1
# 3      1
# 4      1
# ...   ..
# 55927 -1
# 55928  1
# 55929  1
# 55930 -1
# 55931  1
#
# [55932 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#fit Log Regression Model
clf= LogisticRegression()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.79      0.81      0.80      6289
#            0       0.39      0.07      0.11       104
#            1       0.74      0.73      0.74      4794
#
#     accuracy                           0.77     11187
#    macro avg       0.64      0.54      0.55     11187
# weighted avg       0.77      0.77      0.77     11187

# %%
# X_tfidf = tfidf_vect.fit_transform(new_headline_words_df['Headline'])
# print(X_tfidf.shape)
# print(tfidf_vect.get_feature_names())
# X_tfidf = pd.DataFrame(X_tfidf.toarray())
# X_tfidf

# %%
# headline_labels = list()
# for i in range(len(sentiment_headlines)):
#     if(sentiment_headlines[i] < 0):
#         headline_labels.append(-1)
#     elif(sentiment_headlines[i] > 0):
#         headline_labels.append(1)
#     else:
#         headline_labels.append(0)
# pd.DataFrame(headline_labels)
# sentiment_headlines_df = pd.DataFrame(headline_labels)

# %%
# sentiment_titles_df.shape

# %%
# sentiment_headlines_df.shape

# %%
# X= X_tfidf
# y = sentiment_titles_df
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
# #fit Log Regression Model
# clf= LogisticRegression()
# clf.fit(X_train,y_train)
# clf.score(X_test,y_test)
# y_pred = clf.predict(X_test)
# print(classification_report(y_test, y_pred))

# %%
# X= X_tfidf
# y = sentiment_headlines_df
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
# #fit Log Regression Model
# clf= LogisticRegression()
# clf.fit(X_train,y_train)
# clf.score(X_test,y_test)
# y_pred = clf.predict(X_test)
# print(classification_report(y_test, y_pred))
